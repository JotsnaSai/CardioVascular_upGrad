# %% [markdown]
# CARDIOVASCULAR DISEASE PREDICTION
#
# Data Description:
# This dataset is from health domain.           There are 17 columns and 3390 rows.
#
# There are mainly two types of data in this
# 1 Objective: factual information
# 2 Examination: results of medical examination

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
cardio = pd.read_csv("data_cardiovascular_risk.csv")

# %%
cardio
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 0        0   64        2.0   F        YES         3.0     0.0
# 1        1   36        4.0   M         NO         0.0     0.0
# 2        2   46        1.0   F        YES        10.0     0.0
# 3        3   50        1.0   M        YES        20.0     0.0
# 4        4   64        1.0   F        YES        30.0     0.0
# ...    ...  ...        ...  ..        ...         ...     ...
# 3385  3385   60        1.0   F         NO         0.0     0.0
# 3386  3386   46        1.0   F         NO         0.0     0.0
# 3387  3387   44        3.0   M        YES         3.0     0.0
# 3388  3388   60        1.0   M         NO         0.0     NaN
# 3389  3389   54        3.0   F         NO         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    221.0  148.0   85.0    NaN
# ...

# %%
cardio.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# ...

# %%
cardio.shape
# Out:
# (3390, 17)

# %% [markdown]
# There are 3390 rows and 17 columns.

# %%
cardio.describe()
# Out:
#                 id          age    education   cigsPerDay       BPMeds  \
# count  3390.000000  3390.000000  3303.000000  3368.000000  3346.000000
# mean   1694.500000    49.542183     1.970936     9.069477     0.029886
# std     978.753033     8.592878     1.019081    11.879078     0.170299
# min       0.000000    32.000000     1.000000     0.000000     0.000000
# 25%     847.250000    42.000000     1.000000     0.000000     0.000000
# 50%    1694.500000    49.000000     2.000000     0.000000     0.000000
# 75%    2541.750000    56.000000     3.000000    20.000000     0.000000
# max    3389.000000    70.000000     4.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol       sysBP  \
# count      3390.000000   3390.000000  3390.000000  3352.000000  3390.00000
# mean          0.006490      0.315339     0.025664   237.074284   132.60118
# std           0.080309      0.464719     0.158153    45.247430    22.29203
# ...

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
# ...

# %%
cardio.isnull().sum()
# Out:
# id                   0
# age                  0
# education           87
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
cardio.dtypes
# Out:
# id                   int64
# age                  int64
# education          float64
# sex                 object
# is_smoking          object
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
sns.countplot(x='sex', data = cardio, palette="Set2");

# %% [markdown]
# There are more female than male in the dataset.

# %%
print("Gender Ratio (in Percentage):")
print(round(cardio.sex.value_counts() / cardio.sex.count() * 100, 2))
# Out:
# Gender Ratio (in Percentage):
# F    56.73
# M    43.27
# Name: sex, dtype: float64

# %%
sns.countplot(x='sex', hue='prevalentStroke', data = cardio, palette="Set2");

# %% [markdown]
# So here green is no stroke and orange is stroke bar.
# In female the orange bar is slightly high.
# Female are getting more strokes than men.

# %%
sns.distplot(cardio['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# From the above distplot we can see that there are ages between 30-70 in the dataset.
# More ages are between 35-40 and 40-50.
# There are very few people of the age 30-35 and 65-70.

# %%
sns.distplot(cardio['cigsPerDay'])
# Out:
# <AxesSubplot:xlabel='cigsPerDay', ylabel='Density'>

# %% [markdown]
# There are more non-smokers than smokers. There is very little difference i.e., 17.
# Many people who smoke, are taking utmost 20 cigarettes per day.
# Its literally in the dataset that people easily smoke atleast 10 per day.

# %%
sns.boxplot(cardio['heartRate'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Heartrate is normal for all between 60-85, however average heartrate is 72-75.

# %%
corr = cardio[['age', 'diabetes']].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_372b2_row0_col0, #T_372b2_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_372b2_row0_col1, #T_372b2_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_372b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_372b2_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_372b2_level0_col1" class="col_heading level0 col1" >diabetes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_372b2_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_372b2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_372b2_row0_col1" class="data row0 col1" >0.107875</td>
#     </tr>
#     <tr>
#       <th id="T_372b2_level0_row1" class="row_heading level0 row1" >diabetes</th>
#       <td id="T_372b2_row1_col0" class="data row1 col0" >0.107875</td>
# ...

# %% [markdown]
# So from the above correlation between age and diabetes we can say that there is no relation between these two.
# In the correlation, we will consider only if the value is above 0.5. Here the value is 0.1 in diabetes.
# Now a days even small kids are getting diabetes. So it is proved that there is nothing to do with age.

# %%
plt.scatter(cardio['age'], cardio['totChol'])
plt.show()

# %%
plt.scatter(cardio['age'], cardio['glucose'])
plt.show()

# %% [markdown]
# Above both the graphs show that there is nothing to cholesterol and glucose to do with age.

# %%
plt.scatter(cardio['prevalentStroke'], cardio['totChol'])
plt.show()

# %%
plt.scatter(cardio['prevalentStroke'], cardio['heartRate'])
plt.show()

# %% [markdown]
# Stroke is not dependent on cholesterol or heartrate.

# %%
num = cardio["is_smoking"].value_counts("0")
num
# Out:
# NO     0.50236
# YES    0.49764
# Name: is_smoking, dtype: float64

# %%
num_ns = 3390 * 0.50236
num_s = 3390 * 0.49764
print(f"There are  {int(num_ns)}  Non-Smokers and  {int(num_s)}  Smokers in the data set.")
# Out:
# There are  1703  Non-Smokers and  1686  Smokers in the data set.

# %%
cardio.drop("id",axis=1,inplace=True)
cardio
# Out:
#       age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0      64        2.0   F        YES         3.0     0.0                0
# 1      36        4.0   M         NO         0.0     0.0                0
# 2      46        1.0   F        YES        10.0     0.0                0
# 3      50        1.0   M        YES        20.0     0.0                0
# 4      64        1.0   F        YES        30.0     0.0                0
# ...   ...        ...  ..        ...         ...     ...              ...
# 3385   60        1.0   F         NO         0.0     0.0                0
# 3386   46        1.0   F         NO         0.0     0.0                0
# 3387   44        3.0   M        YES         3.0     0.0                0
# 3388   60        1.0   M         NO         0.0     NaN                0
# 3389   54        3.0   F         NO         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %% [markdown]
# Dropped id column because it is of no use

# %%
cardio.drop("education",axis=1,inplace=True)
cardio
# Out:
#       age sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  \
# 0      64   F        YES         3.0     0.0                0             0
# 1      36   M         NO         0.0     0.0                0             1
# 2      46   F        YES        10.0     0.0                0             0
# 3      50   M        YES        20.0     0.0                0             1
# 4      64   F        YES        30.0     0.0                0             0
# ...   ...  ..        ...         ...     ...              ...           ...
# 3385   60   F         NO         0.0     0.0                0             0
# 3386   46   F         NO         0.0     0.0                0             0
# 3387   44   M        YES         3.0     0.0                0             1
# 3388   60   M         NO         0.0     NaN                0             1
# 3389   54   F         NO         0.0     0.0                0             0
#
# ...

# %% [markdown]
# Above I have removed the education column because the data was not appropriate.

# %%
cardio.isnull().sum()
# Out:
# age                  0
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
cardio['cigsPerDay'].fillna(int(cardio['cigsPerDay'].mean()), inplace=True)

# %%
cardio = cardio.fillna({'BPMeds' : '0'})

# %%
cardio['totChol'].fillna(int(cardio['totChol'].median()), inplace=True)

# %%
cardio['BMI'].fillna(int(cardio['BMI'].mean()), inplace=True)

# %%
cardio['glucose'].fillna(int(cardio['glucose'].mean()), inplace=True)

# %%
cardio.isnull().sum()
# Out:
# age                0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          1
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (13, 5))
plt.subplots_adjust(wspace = 0.4)

ax1 = sns.scatterplot(data = cardio, x = 'BMI', y = 'sysBP', hue = 'prevalentStroke', ax = axes.flat[0])
ax1.set_title('weight and ap_hi')

ax2 = sns.scatterplot(data = cardio, x = 'BMI', y = 'diaBP', hue = 'prevalentStroke', ax = axes.flat[1])
ax2.set_title('weight and ap_lo')

sns.despine();

# %%
print("Cardiovascular Disease Presence in Men and Women (in Percentage):")
print(round(cardio.groupby('sex')['prevalentStroke'].value_counts() / cardio.groupby('sex')['prevalentStroke'].count() * 100, 2))
# Out:
# Cardiovascular Disease Presence in Men and Women (in Percentage):
# sex  prevalentStroke
# F    0                  99.27
#      1                   0.73
# M    0                  99.45
#      1                   0.55
# Name: prevalentStroke, dtype: float64

# %%
print("Percentage of men and women who are smoking")
print(round(cardio.groupby('sex')['is_smoking'].value_counts() / cardio.groupby('sex')['is_smoking'].count() * 100, 2))
# Out:
# Percentage of men and women who are smoking
# sex  is_smoking
# F    NO            59.65
#      YES           40.35
# M    YES           62.10
#      NO            37.90
# Name: is_smoking, dtype: float64

# %%
numeric_cols = cardio.select_dtypes(include = np.number).columns.tolist()
print("Numerical Columns:", numeric_cols)

categorical_cols = cardio.select_dtypes(include = 'object').columns.tolist()
print("Categorical Columns:", categorical_cols)
# Out:
# Numerical Columns: ['age', 'cigsPerDay', 'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD']
# Categorical Columns: ['sex', 'is_smoking', 'BPMeds']

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (18, 8))

fig.suptitle('Categorical Columns Based on Cardio', y = 0.95, fontsize = 16)
plt.subplots_adjust(hspace = 0.4, wspace = 0.4)

for pos, name in enumerate(categorical_cols[:-1]):
  sns.countplot(data = cardio, x = name, hue = 'prevalentStroke', ax = axes.flat[pos], alpha = 0.5);

sns.despine()
